# %% [markdown]
# ## Migrando dados da Planilha para um script de inserção

# %% [markdown]
# #### Preparando ambiente

# %%
import pandas as pd

# %%
df_planilha = pd.read_excel("../data/eventify.xlsx", header=0)
df_planilha.head()
# Out:
#         Identificação da tarefa  \
# 0  QK9znuqXgUim5BTZVwdQo2QAABNA
# 1  5G2nqGU3vEy0JBklya4NeWQAIAd1
# 2  1yNcJDtA_kqWI2tSzh2bfGQABqyY
# 3  ljX6KUZrakqZjHTfS8RRI2QAFYZk
# 4  aVVYRsCeL0iTBHBQNlk0ZWQAKvuK
#
#                                       Nome da tarefa  \
# 0  Correção de Avaliação na Home / Formulário Din...
# 1                               Revisão do Front-end
# 2                                ⚠️ Dados do Projeto
# 3                          Serviços para FE na Cloud
# 4                                      Log de acesso
#
#                          Nome do Bucket     Progresso Prioridade  \
# 0             🔨 Refatoração - Front-End     Concluída      Média
# 1     🔄 SPRINT IV - Web-App (Front-end)     Concluída      Média
# 2                               📌 Mural  Não iniciada      Média
# 3  🔄 SPRINT IV - Infra e Comp. em Nuvem     Concluída      Média
# 4     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
#
#                         Atribuído a                        Criado por  \
# 0    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 1    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 2                               NaN    LEONARDO VASCONCELOS PAULINO .
# 3  GUILHERME HENRIQUE ANGELO DIAS .  GUILHERME HENRIQUE ANGELO DIAS .
# 4        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
#
#     Criado em Data de início Data de conclusão  É Recorrente  Atrasados  \
# 0  16/09/2023            NaN               NaN         False      False
# 1  12/09/2023            NaN               NaN         False      False
# 2  27/08/2023            NaN               NaN         False      False
# 3  17/08/2023            NaN               NaN         False      False
# 4  21/07/2023            NaN               NaN         False      False
#
#   Concluído em                     Concluída por  \
# 0   17/09/2023    LEONARDO VASCONCELOS PAULINO .
# 1   17/09/2023    LEONARDO VASCONCELOS PAULINO .
# 2          NaN                               NaN
# 3   16/09/2023  GUILHERME HENRIQUE ANGELO DIAS .
# 4          NaN                               NaN
#
#   Itens concluídos da lista de verificação Itens da lista de verificação  \
# 0                                      NaN                           NaN
# 1                                      NaN                           NaN
# 2                                      NaN                           NaN
# 3                                      NaN                           NaN
# 4                                      NaN                           NaN
#
#   Rótulos                                          Descrição
# 0       5  _x000d_\nRefatorar código que puxa valores das...
# 1       8  _x000d_\nRevisar se todas as telas do front-en...
# 2     NaN  _x000d_\nAWS_x000d_\n_x000d_\nlogin: helder.al...
# 3      13  _x000d_\nCriar código shell script que faça a ...
# 4      21  _x000d_\nAssim que o usuário utilizar alguma d...

# %% [markdown]
# #### Eliminando o Mural

# %%
qtd_antes = df_planilha.shape[0]
df_planilha = df_planilha[df_planilha["Nome do Bucket"] != "📌 Mural"]
qtd_depois = df_planilha.shape[0]
print(f"Antes: {qtd_antes} | Depois: {qtd_depois}")
# Out:
# Antes: 163 | Depois: 155

# %% [markdown]
# #### Limpando os caracteres especiais do campo Descrição

# %%
df_planilha["Descrição"] = df_planilha["Descrição"].str.replace("\n", " ")
df_planilha["Descrição"] = df_planilha["Descrição"].str.replace("\r", " ")
df_planilha["Descrição"] = df_planilha["Descrição"].str.replace("\t", " ")
df_planilha["Descrição"] = df_planilha["Descrição"].str.replace("_x000d_", "")

df_planilha.head()
# Out:
#         Identificação da tarefa  \
# 0  QK9znuqXgUim5BTZVwdQo2QAABNA
# 1  5G2nqGU3vEy0JBklya4NeWQAIAd1
# 3  ljX6KUZrakqZjHTfS8RRI2QAFYZk
# 4  aVVYRsCeL0iTBHBQNlk0ZWQAKvuK
# 5  dH3_yAQOXEKxaqaZZqlNpGQAPlpF
#
#                                       Nome da tarefa  \
# 0  Correção de Avaliação na Home / Formulário Din...
# 1                               Revisão do Front-end
# 3                          Serviços para FE na Cloud
# 4                                      Log de acesso
# 5                  Paginação (Pesquisa - Formulário)
#
#                          Nome do Bucket     Progresso Prioridade  \
# 0             🔨 Refatoração - Front-End     Concluída      Média
# 1     🔄 SPRINT IV - Web-App (Front-end)     Concluída      Média
# 3  🔄 SPRINT IV - Infra e Comp. em Nuvem     Concluída      Média
# 4     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
# 5     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
#
#                         Atribuído a                        Criado por  \
# 0    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 1    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 3  GUILHERME HENRIQUE ANGELO DIAS .  GUILHERME HENRIQUE ANGELO DIAS .
# 4        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
# 5        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
#
#     Criado em Data de início Data de conclusão  É Recorrente  Atrasados  \
# 0  16/09/2023            NaN               NaN         False      False
# 1  12/09/2023            NaN               NaN         False      False
# 3  17/08/2023            NaN               NaN         False      False
# 4  21/07/2023            NaN               NaN         False      False
# 5  16/06/2023            NaN               NaN         False      False
#
#   Concluído em                     Concluída por  \
# 0   17/09/2023    LEONARDO VASCONCELOS PAULINO .
# 1   17/09/2023    LEONARDO VASCONCELOS PAULINO .
# 3   16/09/2023  GUILHERME HENRIQUE ANGELO DIAS .
# 4          NaN                               NaN
# 5          NaN                               NaN
#
#   Itens concluídos da lista de verificação Itens da lista de verificação  \
# 0                                      NaN                           NaN
# 1                                      NaN                           NaN
# 3                                      NaN                           NaN
# 4                                      NaN                           NaN
# 5                                      NaN                           NaN
#
#   Rótulos                                          Descrição
# 0       5   Refatorar código que puxa valores das avaliaç...
# 1       8   Revisar se todas as telas do front-end estão ...
# 3      13   Criar código shell script que faça a instalaç...
# 4      21   Assim que o usuário utilizar alguma das segui...
# 5      21   Criar requisições elementos na tela para que ...

# %% [markdown]
# #### Limpando Rótulos para se tornar Fibonacci

# %%
df_planilha["Rótulos"] = df_planilha["Rótulos"].str.replace("[^0-9]", "")
df_planilha["Rótulos"] = df_planilha["Rótulos"].str.replace("ª", "")
df_planilha["Rótulos"] = df_planilha["Rótulos"].str.replace("º", "")
df_planilha["Rótulos"] = df_planilha["Rótulos"].str.replace(";5", "")
df_planilha["Rótulos"] = df_planilha["Rótulos"].str.replace(";AguardarProfessor", "")
df_planilha["Rótulos"] = df_planilha["Rótulos"].str.replace("Aguardar Professor", "")
df_planilha["Rótulos"] = df_planilha["Rótulos"].str.replace(";", "")
df_planilha["Rótulos"] = df_planilha["Rótulos"].str.replace("Sprint", "")
df_planilha.head()
# Out:
#         Identificação da tarefa  \
# 0  QK9znuqXgUim5BTZVwdQo2QAABNA
# 1  5G2nqGU3vEy0JBklya4NeWQAIAd1
# 3  ljX6KUZrakqZjHTfS8RRI2QAFYZk
# 4  aVVYRsCeL0iTBHBQNlk0ZWQAKvuK
# 5  dH3_yAQOXEKxaqaZZqlNpGQAPlpF
#
#                                       Nome da tarefa  \
# 0  Correção de Avaliação na Home / Formulário Din...
# 1                               Revisão do Front-end
# 3                          Serviços para FE na Cloud
# 4                                      Log de acesso
# 5                  Paginação (Pesquisa - Formulário)
#
#                          Nome do Bucket     Progresso Prioridade  \
# 0             🔨 Refatoração - Front-End     Concluída      Média
# 1     🔄 SPRINT IV - Web-App (Front-end)     Concluída      Média
# 3  🔄 SPRINT IV - Infra e Comp. em Nuvem     Concluída      Média
# 4     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
# 5     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
#
#                         Atribuído a                        Criado por  \
# 0    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 1    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 3  GUILHERME HENRIQUE ANGELO DIAS .  GUILHERME HENRIQUE ANGELO DIAS .
# 4        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
# 5        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
#
#     Criado em Data de início Data de conclusão  ...  Atrasados  Concluído em  \
# 0  16/09/2023            NaN               NaN  ...      False    17/09/2023
# 1  12/09/2023            NaN               NaN  ...      False    17/09/2023
# 3  17/08/2023            NaN               NaN  ...      False    16/09/2023
# 4  21/07/2023            NaN               NaN  ...      False           NaN
# 5  16/06/2023            NaN               NaN  ...      False           NaN
#
#                       Concluída por Itens concluídos da lista de verificação  \
# 0    LEONARDO VASCONCELOS PAULINO .                                      NaN
# 1    LEONARDO VASCONCELOS PAULINO .                                      NaN
# 3  GUILHERME HENRIQUE ANGELO DIAS .                                      NaN
# 4                               NaN                                      NaN
# 5                               NaN                                      NaN
#
#   Itens da lista de verificação Rótulos  \
# 0                           NaN       5
# 1                           NaN       8
# 3                           NaN      13
# 4                           NaN      21
# 5                           NaN      21
#
#                                            Descrição      board      section  \
# 0   Refatorar código que puxa valores das avaliaç...             Refatoração
# 1   Revisar se todas as telas do front-end estão ...  Front-end    SPRINT IV
# 3   Criar código shell script que faça a instalaç...               SPRINT IV
# 4   Assim que o usuário utilizar alguma das segui...  Front-end    SPRINT IV
# 5   Criar requisições elementos na tela para que ...  Front-end    SPRINT IV
#
#   status
# 0      2
# 1      2
# 3      2
# 4      0
# 5      0
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Criando o Board e o Section

# %%
boards_sections = df_planilha['Nome do Bucket'].unique()

df_planilha = df_planilha.assign(board="", section="")
df_planilha.head()

for index, row in df_planilha.iterrows():
    if "Back-end" in row["Nome do Bucket"]:
        df_planilha.at[index, "board"] = "Back-end"
    elif "Rest-API" in row["Nome do Bucket"]:
        df_planilha.at[index, "board"] = "Back-end"
    elif "Front-end" in row["Nome do Bucket"]:
        df_planilha.at[index, "board"] = "Front-end"
    elif "Web-App" in row["Nome do Bucket"]:
        df_planilha.at[index, "board"] = "Front-end"
    elif "Teórico" in row["Nome do Bucket"]:
        df_planilha.at[index, "board"] = "Teórico e Outras"
    else:
        df_planilha.at[index, "section"] = "Teórico e Outras"
    
    if "SPRINT IV" in row["Nome do Bucket"]:
        df_planilha.at[index, "section"] = "SPRINT IV"
    elif "SPRINT III" in row["Nome do Bucket"]:
        df_planilha.at[index, "section"] = "SPRINT III"
    elif "SPRINT II" in row["Nome do Bucket"]:
        df_planilha.at[index, "section"] = "SPRINT II"
    elif "SPRINT I" in row["Nome do Bucket"]:
        df_planilha.at[index, "section"] = "SPRINT I"
    elif "Refatoração" in row["Nome do Bucket"]:
        df_planilha.at[index, "section"] = "Refatoração"

df_planilha.head()
# Out:
#         Identificação da tarefa  \
# 0  QK9znuqXgUim5BTZVwdQo2QAABNA
# 1  5G2nqGU3vEy0JBklya4NeWQAIAd1
# 3  ljX6KUZrakqZjHTfS8RRI2QAFYZk
# 4  aVVYRsCeL0iTBHBQNlk0ZWQAKvuK
# 5  dH3_yAQOXEKxaqaZZqlNpGQAPlpF
#
#                                       Nome da tarefa  \
# 0  Correção de Avaliação na Home / Formulário Din...
# 1                               Revisão do Front-end
# 3                          Serviços para FE na Cloud
# 4                                      Log de acesso
# 5                  Paginação (Pesquisa - Formulário)
#
#                          Nome do Bucket     Progresso Prioridade  \
# 0             🔨 Refatoração - Front-End     Concluída      Média
# 1     🔄 SPRINT IV - Web-App (Front-end)     Concluída      Média
# 3  🔄 SPRINT IV - Infra e Comp. em Nuvem     Concluída      Média
# 4     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
# 5     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
#
#                         Atribuído a                        Criado por  \
# 0    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 1    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 3  GUILHERME HENRIQUE ANGELO DIAS .  GUILHERME HENRIQUE ANGELO DIAS .
# 4        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
# 5        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
#
#     Criado em Data de início Data de conclusão  ...  Atrasados  Concluído em  \
# 0  16/09/2023            NaN               NaN  ...      False    17/09/2023
# 1  12/09/2023            NaN               NaN  ...      False    17/09/2023
# 3  17/08/2023            NaN               NaN  ...      False    16/09/2023
# 4  21/07/2023            NaN               NaN  ...      False           NaN
# 5  16/06/2023            NaN               NaN  ...      False           NaN
#
#                       Concluída por Itens concluídos da lista de verificação  \
# 0    LEONARDO VASCONCELOS PAULINO .                                      NaN
# 1    LEONARDO VASCONCELOS PAULINO .                                      NaN
# 3  GUILHERME HENRIQUE ANGELO DIAS .                                      NaN
# 4                               NaN                                      NaN
# 5                               NaN                                      NaN
#
#   Itens da lista de verificação Rótulos  \
# 0                           NaN       5
# 1                           NaN       8
# 3                           NaN      13
# 4                           NaN      21
# 5                           NaN      21
#
#                                            Descrição      board      section  \
# 0   Refatorar código que puxa valores das avaliaç...             Refatoração
# 1   Revisar se todas as telas do front-end estão ...  Front-end    SPRINT IV
# 3   Criar código shell script que faça a instalaç...               SPRINT IV
# 4   Assim que o usuário utilizar alguma das segui...  Front-end    SPRINT IV
# 5   Criar requisições elementos na tela para que ...  Front-end    SPRINT IV
#
#   status
# 0      2
# 1      2
# 3      2
# 4      0
# 5      0
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Criando a coluna status a partir do campo "Concluída em"

# %%
df_planilha["status"] = df_planilha["Concluído em"].apply(lambda x: 2 if pd.notnull(x) else 0)
df_planilha.head()
# Out:
#         Identificação da tarefa  \
# 0  QK9znuqXgUim5BTZVwdQo2QAABNA
# 1  5G2nqGU3vEy0JBklya4NeWQAIAd1
# 3  ljX6KUZrakqZjHTfS8RRI2QAFYZk
# 4  aVVYRsCeL0iTBHBQNlk0ZWQAKvuK
# 5  dH3_yAQOXEKxaqaZZqlNpGQAPlpF
#
#                                       Nome da tarefa  \
# 0  Correção de Avaliação na Home / Formulário Din...
# 1                               Revisão do Front-end
# 3                          Serviços para FE na Cloud
# 4                                      Log de acesso
# 5                  Paginação (Pesquisa - Formulário)
#
#                          Nome do Bucket     Progresso Prioridade  \
# 0             🔨 Refatoração - Front-End     Concluída      Média
# 1     🔄 SPRINT IV - Web-App (Front-end)     Concluída      Média
# 3  🔄 SPRINT IV - Infra e Comp. em Nuvem     Concluída      Média
# 4     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
# 5     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
#
#                         Atribuído a                        Criado por  \
# 0    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 1    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 3  GUILHERME HENRIQUE ANGELO DIAS .  GUILHERME HENRIQUE ANGELO DIAS .
# 4        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
# 5        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
#
#     Criado em Data de início Data de conclusão  ...  Atrasados  Concluído em  \
# 0  16/09/2023            NaN               NaN  ...      False    17/09/2023
# 1  12/09/2023            NaN               NaN  ...      False    17/09/2023
# 3  17/08/2023            NaN               NaN  ...      False    16/09/2023
# 4  21/07/2023            NaN               NaN  ...      False           NaN
# 5  16/06/2023            NaN               NaN  ...      False           NaN
#
#                       Concluída por Itens concluídos da lista de verificação  \
# 0    LEONARDO VASCONCELOS PAULINO .                                      NaN
# 1    LEONARDO VASCONCELOS PAULINO .                                      NaN
# 3  GUILHERME HENRIQUE ANGELO DIAS .                                      NaN
# 4                               NaN                                      NaN
# 5                               NaN                                      NaN
#
#   Itens da lista de verificação Rótulos  \
# 0                           NaN       5
# 1                           NaN       8
# 3                           NaN      13
# 4                           NaN      21
# 5                           NaN      21
#
#                                            Descrição      board      section  \
# 0   Refatorar código que puxa valores das avaliaç...             Refatoração
# 1   Revisar se todas as telas do front-end estão ...  Front-end    SPRINT IV
# 3   Criar código shell script que faça a instalaç...               SPRINT IV
# 4   Assim que o usuário utilizar alguma das segui...  Front-end    SPRINT IV
# 5   Criar requisições elementos na tela para que ...  Front-end    SPRINT IV
#
#   status
# 0      2
# 1      2
# 3      2
# 4      0
# 5      0
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Criando a coluna time a partir de "Rótulos"

# %%
df_planilha["time"] = df_planilha["Rótulos"].apply(lambda x: int(x) if pd.notnull(x) else 0)
df_planilha["time"] = df_planilha["time"].apply(lambda x: x/2)
df_planilha["time"] = df_planilha["time"].apply(lambda x: int(x) if pd.notnull(x) else 0)
df_planilha.head()
# Out:
#         Identificação da tarefa  \
# 0  QK9znuqXgUim5BTZVwdQo2QAABNA
# 1  5G2nqGU3vEy0JBklya4NeWQAIAd1
# 3  ljX6KUZrakqZjHTfS8RRI2QAFYZk
# 4  aVVYRsCeL0iTBHBQNlk0ZWQAKvuK
# 5  dH3_yAQOXEKxaqaZZqlNpGQAPlpF
#
#                                       Nome da tarefa  \
# 0  Correção de Avaliação na Home / Formulário Din...
# 1                               Revisão do Front-end
# 3                          Serviços para FE na Cloud
# 4                                      Log de acesso
# 5                  Paginação (Pesquisa - Formulário)
#
#                          Nome do Bucket     Progresso Prioridade  \
# 0             🔨 Refatoração - Front-End     Concluída      Média
# 1     🔄 SPRINT IV - Web-App (Front-end)     Concluída      Média
# 3  🔄 SPRINT IV - Infra e Comp. em Nuvem     Concluída      Média
# 4     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
# 5     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
#
#                         Atribuído a                        Criado por  \
# 0    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 1    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 3  GUILHERME HENRIQUE ANGELO DIAS .  GUILHERME HENRIQUE ANGELO DIAS .
# 4        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
# 5        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
#
#     Criado em Data de início Data de conclusão  ...  Concluído em  \
# 0  16/09/2023            NaN               NaN  ...    17/09/2023
# 1  12/09/2023            NaN               NaN  ...    17/09/2023
# 3  17/08/2023            NaN               NaN  ...    16/09/2023
# 4  21/07/2023            NaN               NaN  ...           NaN
# 5  16/06/2023            NaN               NaN  ...           NaN
#
#                       Concluída por Itens concluídos da lista de verificação  \
# 0    LEONARDO VASCONCELOS PAULINO .                                      NaN
# 1    LEONARDO VASCONCELOS PAULINO .                                      NaN
# 3  GUILHERME HENRIQUE ANGELO DIAS .                                      NaN
# 4                               NaN                                      NaN
# 5                               NaN                                      NaN
#
#   Itens da lista de verificação Rótulos  \
# 0                           NaN       5
# 1                           NaN       8
# 3                           NaN      13
# 4                           NaN      21
# 5                           NaN      21
#
#                                            Descrição      board      section  \
# 0   Refatorar código que puxa valores das avaliaç...             Refatoração
# 1   Revisar se todas as telas do front-end estão ...  Front-end    SPRINT IV
# 3   Criar código shell script que faça a instalaç...               SPRINT IV
# 4   Assim que o usuário utilizar alguma das segui...  Front-end    SPRINT IV
# 5   Criar requisições elementos na tela para que ...  Front-end    SPRINT IV
#
#   status time
# 0      2    2
# 1      2    4
# 3      2    6
# 4      0   10
# 5      0   10
#
# [5 rows x 22 columns]

# %% [markdown]
# #### Criando a coluna data_estimada a partir de time

# %%
df_planilha["Criado em"] = pd.to_datetime(df_planilha["Criado em"], format="%d/%m/%Y")
df_planilha["data_estimada"] = df_planilha["Criado em"] + pd.to_timedelta(df_planilha["time"], unit='d')
df_planilha["data_estimada"] = df_planilha["data_estimada"].dt.strftime("%Y-%m-%d")
df_planilha.head()
# Out:
#         Identificação da tarefa  \
# 0  QK9znuqXgUim5BTZVwdQo2QAABNA
# 1  5G2nqGU3vEy0JBklya4NeWQAIAd1
# 3  ljX6KUZrakqZjHTfS8RRI2QAFYZk
# 4  aVVYRsCeL0iTBHBQNlk0ZWQAKvuK
# 5  dH3_yAQOXEKxaqaZZqlNpGQAPlpF
#
#                                       Nome da tarefa  \
# 0  Correção de Avaliação na Home / Formulário Din...
# 1                               Revisão do Front-end
# 3                          Serviços para FE na Cloud
# 4                                      Log de acesso
# 5                  Paginação (Pesquisa - Formulário)
#
#                          Nome do Bucket     Progresso Prioridade  \
# 0             🔨 Refatoração - Front-End     Concluída      Média
# 1     🔄 SPRINT IV - Web-App (Front-end)     Concluída      Média
# 3  🔄 SPRINT IV - Infra e Comp. em Nuvem     Concluída      Média
# 4     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
# 5     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
#
#                         Atribuído a                        Criado por  \
# 0    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 1    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 3  GUILHERME HENRIQUE ANGELO DIAS .  GUILHERME HENRIQUE ANGELO DIAS .
# 4        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
# 5        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
#
#    Criado em Data de início Data de conclusão  ...  \
# 0 2023-09-16            NaN               NaN  ...
# 1 2023-09-12            NaN               NaN  ...
# 3 2023-08-17            NaN               NaN  ...
# 4 2023-07-21            NaN               NaN  ...
# 5 2023-06-16            NaN               NaN  ...
#
#                       Concluída por  Itens concluídos da lista de verificação  \
# 0    LEONARDO VASCONCELOS PAULINO .                                       NaN
# 1    LEONARDO VASCONCELOS PAULINO .                                       NaN
# 3  GUILHERME HENRIQUE ANGELO DIAS .                                       NaN
# 4                               NaN                                       NaN
# 5                               NaN                                       NaN
#
#   Itens da lista de verificação Rótulos  \
# 0                           NaN       5
# 1                           NaN       8
# 3                           NaN      13
# 4                           NaN      21
# 5                           NaN      21
#
#                                            Descrição      board      section  \
# 0   Refatorar código que puxa valores das avaliaç...             Refatoração
# 1   Revisar se todas as telas do front-end estão ...  Front-end    SPRINT IV
# 3   Criar código shell script que faça a instalaç...               SPRINT IV
# 4   Assim que o usuário utilizar alguma das segui...  Front-end    SPRINT IV
# 5   Criar requisições elementos na tela para que ...  Front-end    SPRINT IV
#
#   status time data_estimada
# 0      2    2    2023-09-18
# 1      2    4    2023-09-16
# 3      2    6    2023-08-23
# 4      0   10    2023-07-31
# 5      0   10    2023-06-26
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Criando uma coluna de ID para montar os relacionamentos

# %%
df_planilha = df_planilha.assign(id=range(1, len(df_planilha) + 1))
df_planilha.head()
# Out:
#         Identificação da tarefa  \
# 0  QK9znuqXgUim5BTZVwdQo2QAABNA
# 1  5G2nqGU3vEy0JBklya4NeWQAIAd1
# 3  ljX6KUZrakqZjHTfS8RRI2QAFYZk
# 4  aVVYRsCeL0iTBHBQNlk0ZWQAKvuK
# 5  dH3_yAQOXEKxaqaZZqlNpGQAPlpF
#
#                                       Nome da tarefa  \
# 0  Correção de Avaliação na Home / Formulário Din...
# 1                               Revisão do Front-end
# 3                          Serviços para FE na Cloud
# 4                                      Log de acesso
# 5                  Paginação (Pesquisa - Formulário)
#
#                          Nome do Bucket     Progresso Prioridade  \
# 0             🔨 Refatoração - Front-End     Concluída      Média
# 1     🔄 SPRINT IV - Web-App (Front-end)     Concluída      Média
# 3  🔄 SPRINT IV - Infra e Comp. em Nuvem     Concluída      Média
# 4     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
# 5     🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
#
#                         Atribuído a                        Criado por  \
# 0    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 1    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 3  GUILHERME HENRIQUE ANGELO DIAS .  GUILHERME HENRIQUE ANGELO DIAS .
# 4        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
# 5        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
#
#    Criado em Data de início Data de conclusão  ...  \
# 0 2023-09-16            NaN               NaN  ...
# 1 2023-09-12            NaN               NaN  ...
# 3 2023-08-17            NaN               NaN  ...
# 4 2023-07-21            NaN               NaN  ...
# 5 2023-06-16            NaN               NaN  ...
#
#    Itens concluídos da lista de verificação  Itens da lista de verificação  \
# 0                                       NaN                            NaN
# 1                                       NaN                            NaN
# 3                                       NaN                            NaN
# 4                                       NaN                            NaN
# 5                                       NaN                            NaN
#
#   Rótulos                                          Descrição      board  \
# 0       5   Refatorar código que puxa valores das avaliaç...
# 1       8   Revisar se todas as telas do front-end estão ...  Front-end
# 3      13   Criar código shell script que faça a instalaç...
# 4      21   Assim que o usuário utilizar alguma das segui...  Front-end
# 5      21   Criar requisições elementos na tela para que ...  Front-end
#
#        section status time data_estimada id
# 0  Refatoração      2    2    2023-09-18  1
# 1    SPRINT IV      2    4    2023-09-16  2
# 3    SPRINT IV      2    6    2023-08-23  3
# 4    SPRINT IV      0   10    2023-07-31  4
# 5    SPRINT IV      0   10    2023-06-26  5
#
# [5 rows x 24 columns]

# %% [markdown]
# #### Atribuindo a cada usuário a tarefa
#
# - [1] BRAYAN COELHO DE AQUINO
# - [2] GUILHERME HENRIQUE ANGELO DIAS
# - [3] HELDER DAVIDSON RODRIGUES ALVARENGA
# - [4] LEONARDO VASCONCELOS PAULINO
# - [5] VICTOR HUGO MARQUES DO NASCIMENTO
# - [6] VITOR GONÇALVES DA SILVA

# %%
df_usuario_tarefa = pd.DataFrame(columns=['id_usuario', 'id_tarefa'])

for index, row in df_planilha.iterrows():
    atribuido_a = str(row["Atribuído a"])
    if "BRAYAN COELHO DE AQUINO" in atribuido_a:
        df_usuario_tarefa = pd.concat([df_usuario_tarefa, pd.DataFrame({"id_usuario": 1, "id_tarefa": row["id"]}, index=[0])], ignore_index=True)
    
    if "GUILHERME HENRIQUE ANGELO DIAS" in atribuido_a:
        df_usuario_tarefa = pd.concat([df_usuario_tarefa, pd.DataFrame({"id_usuario": 2, "id_tarefa": row["id"]}, index=[0])], ignore_index=True)
    
    if "HELDER DAVIDSON RODRIGUES ALVARENGA" in atribuido_a:
        df_usuario_tarefa = pd.concat([df_usuario_tarefa, pd.DataFrame({"id_usuario": 3, "id_tarefa": row["id"]}, index=[0])], ignore_index=True)
    
    if "LEONARDO VASCONCELOS PAULINO" in atribuido_a:
        df_usuario_tarefa = pd.concat([df_usuario_tarefa, pd.DataFrame({"id_usuario": 4, "id_tarefa": row["id"]}, index=[0])], ignore_index=True)
    
    if "VICTOR HUGO MARQUES DO NASCIMENTO" in atribuido_a:
        df_usuario_tarefa = pd.concat([df_usuario_tarefa, pd.DataFrame({"id_usuario": 5, "id_tarefa": row["id"]}, index=[0])], ignore_index=True)
    
    if "VITOR GONÇALVES DA SILVA" in atribuido_a:
        df_usuario_tarefa = pd.concat([df_usuario_tarefa, pd.DataFrame({"id_usuario": 6, "id_tarefa": row["id"]}, index=[0])], ignore_index=True)

df_usuario_tarefa.head()
# Out:
#   id_usuario id_tarefa
# 0          4         1
# 1          4         2
# 2          2         3
# 3          6         4
# 4          6         5

# %%
df_usuario_tarefa.shape[0]
# Out:
# 220

# %% [markdown]
# #### Criando a tabela de Board

# %%
df_boards = pd.DataFrame(columns=['id', 'name'])
df_boards = df_planilha[['board']].drop_duplicates().reset_index(drop=True)
df_boards = df_boards.rename(columns={"board": "name"})
df_boards = df_boards[df_boards["name"] != ""]
df_boards = df_boards.assign(id=range(1, len(df_boards) + 1))
df_boards.head()
# Out:
#                name  id
# 1         Front-end   1
# 2          Back-end   2
# 3  Teórico e Outras   3

# %% [markdown]
# #### Criando o dataframe de Sections Unificados para usar mais tarde

# %%
df_sections_unificados = pd.DataFrame(columns=['id', 'name'])
df_sections_unificados = df_planilha[['section']].drop_duplicates().reset_index(drop=True)
df_sections_unificados = df_sections_unificados.assign(id=range(1, len(df_sections_unificados) + 1))
df_sections_unificados = df_sections_unificados.rename(columns={"section": "name"})
df_sections_unificados = df_sections_unificados[df_sections_unificados["name"] != ""]
df_sections_unificados.head()
# Out:
#           name  id
# 0  Refatoração   1
# 1    SPRINT IV   2
# 2   SPRINT III   3
# 3    SPRINT II   4
# 4     SPRINT I   5

# %% [markdown]
# #### Criando a tabela de Sections

# %%
data = ["SPRINT I", 1], ["SPRINT II", 2], ["SPRINT III", 3], ["Refatoração", 4], ["SPRINT IV", 5]
df_sections_ordenados = pd.DataFrame(data, columns=['name', 'id'])
df_sections_ordenados.head()
# Out:
#           name  id
# 0     SPRINT I   1
# 1    SPRINT II   2
# 2   SPRINT III   3
# 3  Refatoração   4
# 4    SPRINT IV   5

# %% [markdown]
# #### Criando a tabela de sections relacionada ao board

# %%
# Para cada registro de df_sections_ordenados, pegar todos os ids de df_boards e criar uma ocorrência dentro de um novo dataframe chamado df_sections

df_sections = pd.DataFrame(columns=['id', 'name', 'board_id'])

for index, row in df_sections_ordenados.iterrows():
    for index2, row2 in df_boards.iterrows():
        df_sections = pd.concat([df_sections, pd.DataFrame({"id": row["id"], "name": row["name"], "board_id": row2["id"]}, index=[0])], ignore_index=True)

df_sections.head(20)
# Out:
#    id         name board_id
# 0   1     SPRINT I        1
# 1   1     SPRINT I        2
# 2   1     SPRINT I        3
# 3   2    SPRINT II        1
# 4   2    SPRINT II        2
# 5   2    SPRINT II        3
# 6   3   SPRINT III        1
# 7   3   SPRINT III        2
# 8   3   SPRINT III        3
# 9   4  Refatoração        1
# 10  4  Refatoração        2
# 11  4  Refatoração        3
# 12  5    SPRINT IV        1
# 13  5    SPRINT IV        2
# 14  5    SPRINT IV        3

# %% [markdown]
# #### Criando a tabela de tarefas a partir da planilha

# %%
df_planilha.head(100)
# Out:
#           Identificação da tarefa  \
# 0    QK9znuqXgUim5BTZVwdQo2QAABNA
# 1    5G2nqGU3vEy0JBklya4NeWQAIAd1
# 3    ljX6KUZrakqZjHTfS8RRI2QAFYZk
# 4    aVVYRsCeL0iTBHBQNlk0ZWQAKvuK
# 5    dH3_yAQOXEKxaqaZZqlNpGQAPlpF
# ..                            ...
# 103  ffCuF249EkOnX-EPfgXm5GQAKJYu
# 104  kNKtUmTe_kG8qap7iybb_2QAFsji
# 105  E7eDquvx8UyyvDUDdhSsy2QABad8
# 106  5KNaeLYDDUa_ft0JHKwbiWQAGIX4
# 107  FFjI1BlN9UejOUtBtTbE0WQAD1Uj
#
#                                         Nome da tarefa  \
# 0    Correção de Avaliação na Home / Formulário Din...
# 1                                 Revisão do Front-end
# 3                            Serviços para FE na Cloud
# 4                                        Log de acesso
# 5                    Paginação (Pesquisa - Formulário)
# ..                                                 ...
# 103                           C1 - Pesquisa - Back-end
# 104                C2 - Controle de Agenda - Front-end
# 105                     C1 - Institucional - Front-end
# 106                            Proprietário/orcamentos
# 107                                 Tratamento de Erro
#
#                            Nome do Bucket     Progresso Prioridade  \
# 0               🔨 Refatoração - Front-End     Concluída      Média
# 1       🔄 SPRINT IV - Web-App (Front-end)     Concluída      Média
# 3    🔄 SPRINT IV - Infra e Comp. em Nuvem     Concluída      Média
# 4       🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
# 5       🔄 SPRINT IV - Web-App (Front-end)  Não iniciada      Média
# ..                                    ...           ...        ...
# 103  🔄 SPRINT III - Checkout Apresentação     Concluída      Média
# 104  🔄 SPRINT III - Checkout Apresentação     Concluída      Média
# 105  🔄 SPRINT III - Checkout Apresentação     Concluída      Média
# 106     🔄 SPRINT III - WebApp (Front-end)     Concluída      Média
# 107     🔄 SPRINT III - WebApp (Front-end)     Concluída      Média
#
#                           Atribuído a                        Criado por  \
# 0      LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 1      LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 3    GUILHERME HENRIQUE ANGELO DIAS .  GUILHERME HENRIQUE ANGELO DIAS .
# 4          VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
# 5          VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
# ..                                ...                               ...
# 103    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 104        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
# 105        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
# 106    LEONARDO VASCONCELOS PAULINO .    LEONARDO VASCONCELOS PAULINO .
# 107        VITOR GONÇALVES DA SILVA .    LEONARDO VASCONCELOS PAULINO .
#
#       Criado em Data de início Data de conclusão  ...  Atrasados  \
# 0    16/09/2023            NaN               NaN  ...      False
# 1    12/09/2023            NaN               NaN  ...      False
# 3    17/08/2023            NaN               NaN  ...      False
# 4    21/07/2023            NaN               NaN  ...      False
# 5    16/06/2023            NaN               NaN  ...      False
# ..          ...            ...               ...  ...        ...
# 103  29/05/2023            NaN               NaN  ...      False
# 104  29/05/2023            NaN               NaN  ...      False
# 105  28/05/2023            NaN               NaN  ...      False
# 106  11/04/2023            NaN        31/05/2023  ...      False
# 107  30/04/2023            NaN        30/05/2023  ...      False
#
#      Concluído em                     Concluída por  \
# 0      17/09/2023    LEONARDO VASCONCELOS PAULINO .
# 1      17/09/2023    LEONARDO VASCONCELOS PAULINO .
# 3      16/09/2023  GUILHERME HENRIQUE ANGELO DIAS .
# 4             NaN                               NaN
# 5             NaN                               NaN
# ..            ...                               ...
# 103    29/05/2023    LEONARDO VASCONCELOS PAULINO .
# 104    29/05/2023        VITOR GONÇALVES DA SILVA .
# 105    29/05/2023        VITOR GONÇALVES DA SILVA .
# 106    28/05/2023    LEONARDO VASCONCELOS PAULINO .
# 107    28/05/2023    LEONARDO VASCONCELOS PAULINO .
#
#     Itens concluídos da lista de verificação Itens da lista de verificação  \
# 0                                        NaN                           NaN
# 1                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# 5                                        NaN                           NaN
# ..                                       ...                           ...
# 103                                      NaN                           NaN
# 104                                      NaN                           NaN
# 105                                      NaN                           NaN
# 106                                      NaN                           NaN
# 107                                      NaN                           NaN
#
#     Rótulos                                          Descrição      board  \
# 0         5  _x000d_\nRefatorar código que puxa valores das...
# 1         8  _x000d_\nRevisar se todas as telas do front-en...  Front-end
# 3        13  _x000d_\nCriar código shell script que faça a ...
# 4        21  _x000d_\nAssim que o usuário utilizar alguma d...  Front-end
# 5        21  _x000d_\nCriar requisições elementos na tela p...  Front-end
# ..      ...                                                ...        ...
# 103       3  Adicionar ignore case quando for buscar pelo n...
# 104       8  Criar tela que deverá permitir ao proprietário...
# 105       2  Inserir na código do site institucional as ima...
# 106       8  H18 H19 H20 H21\n\nRequerimentos:\nEstilização...  Front-end
# 107       8  G5 G6\n\nRequerimentos:\nEstilização completa\...  Front-end
#
#          section   id
# 0    Refatoração    1
# 1       SPRINT I    2
# 3       SPRINT I    3
# 4       SPRINT I    4
# 5       SPRINT I    5
# ..           ...  ...
# 103     SPRINT I   96
# 104     SPRINT I   97
# 105     SPRINT I   98
# 106     SPRINT I   99
# 107     SPRINT I  100
#
# [100 rows x 21 columns]

# %%
df
